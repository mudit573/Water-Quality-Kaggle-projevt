# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'E:\kaggle\water_potability.csv')

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# # data cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# # missing value handeling

# %%
# fill the missing mean value

# %%
data.fillna(data.mean(),inplace=True)
#or data =data.fillna(data.mean(),)

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# # explratory data analysis

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.469956    32.879761   8768.570828     1.583085    36.142612
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.080795   196.967627  20927.833607     7.130299   333.775777
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        15.769881     0.780382     0.487849
# ...

# %% [markdown]
# #dimantionality reduction using heatmap

# %%
sns.heatmap(data.corr(),annot=True,cmap='terrain')
fig = plt.gcf()  #numbers
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Check the box plot

# %%
data.boxplot(figsize=(16,8))
plt.show()

# %%
data['Solids'].describe()
# Out:
# count     3276.000000
# mean     22014.092526
# std       8768.570828
# min        320.942611
# 25%      15666.690297
# 50%      20927.833607
# 75%      27332.762127
# max      61227.196008
# Name: Solids, dtype: float64

# %% [markdown]
# #not removing the outliers bcz it may be imp to decsribe the quality of water

# %%
#check the balance of data

# %%
data['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
sns.countplot(data['Potability'])
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.hist(figsize=(14,12))
plt.show()

# %%
#coorelation btw ph and hardness
#sns.barplot(x=data['ph'],y=data['Hardness'],hue=data['Potability'])
#plt.show()

# %%
sns.scatterplot(x=data['ph'],y=data['Potability'])
plt.show()

# %% [markdown]
# # Partitioning

# %%
X = data.drop('Potability',axis=1)  # input data

# %%
y = data['Potability']   #target variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X,y, test_size=0.2, shuffle=True, random_state=13)

# %% [markdown]
# # Model Training

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='gini', min_samples_split= 9, splitter= 'best')

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=9)

# %%
y_test
# Out:
# 909     0
# 1641    0
# 1080    1
# 3140    1
# 2976    0
#        ..
# 1363    0
# 134     0
# 197     0
# 1501    1
# 441     0
# Name: Potability, Length: 656, dtype: int64

# %%
Y_prediction = dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(Y_prediction,y_test)*100
# Out:
# 58.6890243902439

# %%
confusion_matrix(Y_prediction,y_test)
# Out:
# array([[278, 142],
#        [129, 107]], dtype=int64)

# %% [markdown]
# # Model OPtimization // Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

dt = DecisionTreeClassifier()
criterion = ["gini","entropy"]
splitter = ['best','random']
min_samples_split = range(1,10)

Parameters = dict(criterion = criterion, splitter = splitter, min_samples_split = min_samples_split )
cv = RepeatedStratifiedKFold(n_splits=5,random_state=13)

grid_search_cv_dt = GridSearchCV(estimator=dt, param_grid=Parameters, scoring='accuracy', cv = cv)

# %%
grid_search_cv_dt.fit(X_train,y_train)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 903, in fit
#     super().fit(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 238, in fit
#     raise ValueError("min_samples_split must be an integer "
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
print(grid_search_cv_dt.best_params_)
# Out:
# {'criterion': 'gini', 'min_samples_split': 9, 'splitter': 'best'}

# %%
prediction_grid = grid_search_cv_dt.predict(X_test)

# %%
accuracy_score(prediction_grid,y_test)*100
# Out:
# 57.3170731707317

# %%
confusion_matrix(prediction_grid,y_test)
# Out:
# array([[272, 145],
#        [135, 104]], dtype=int64)
